# %% [markdown]
# # Diabetes Data-set

# %% [markdown]
# ### Diabetes data set for prediction

# %% [markdown]
# https://www.kaggle.com/datasets/pritsheta/diabetes-dataset

# %% [markdown]
# ![image.png](../Images/Diabetes.png)

# %% [markdown]
# ### Library & Data Import

# %%
import numpy as np
import pandas as pd

# %%
X_train = pd.read_csv('../Datasets/Diabetes_X_train.csv')
X_test = pd.read_csv('../Datasets/Diabetes_X_test.csv')
y_train = pd.read_csv('../Datasets/Diabetes_y_train.csv')

# %%
X_train
# Out:
#       ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0            8      126             88             36      108  38.5
# 1      1            0       74             52             10       36  27.8
# 2      2            1      140             74             26      180  24.1
# 3      3            6      162             62              0        0  24.3
# 4      4            2       94             68             18       76  26.0
# ..   ...          ...      ...            ...            ...      ...   ...
# 609  761            5      104             74              0        0  28.8
# 610  762            4      132             86             31        0  28.0
# 611  763            6       80             66             30        0  26.2
# 612  764            8      197             74              0        0  25.9
# 613  766            2       56             56             28       45  24.2
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
X_test
# Out:
#       ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0     13            1       97             68             21        0  27.2
# 1     18            8      100             76              0        0  38.7
# 2     29            2       71             70             27        0  28.0
# 3     33            1      119             86             39      220  45.6
# 4     34            4       85             58             22       49  27.8
# ..   ...          ...      ...            ...            ...      ...   ...
# 149  751            6      134             70             23      130  35.4
# 150  752            4      151             90             38        0  29.7
# 151  759            1       82             64             13       95  21.2
# 152  765            9      184             85             15        0  30.0
# 153  767            8      188             78              0        0  47.9
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
y_train
# Out:
#       ID  Outcome
# 0      0        0
# 1      1        0
# 2      2        0
# 3      3        1
# 4      4        0
# ..   ...      ...
# 609  761        0
# 610  762        0
# 611  763        0
# 612  764        1
# 613  766        0
#
# [614 rows x 2 columns]
