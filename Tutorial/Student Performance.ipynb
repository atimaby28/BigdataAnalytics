# %% [markdown]
# # Student Performance Data Set

# %% [markdown]
# ### This data approach student achievement in secondary education of two Portuguese schools.

# %% [markdown]
# https://www.kaggle.com/datasets/ishandutta/student-performance-data-set

# %% [markdown]
# ![image.png](../Images/Student.png)

# %% [markdown]
# #### [ 데이터 설명 ]
#
# - 1044명의 학생 데이터 : 학교 / 성별 / 나이 / 주소 / 가족 구성원 / 아버지 교육수준 / 어머니 교육수준 등의 feature
#
# |Feature|Definition|Value|
# |:------|:---------|:------------|
# |school| 학생의 학교 |'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira |
# |sex| 성별 | 'F' - female or 'M' - male |
# |age| 나이 | from 15 to 22 |
# |address| 주소  |'U' - urban or 'R' - rural |
# |famsize| 가족 구성원 수|   LE3' - less or equal to 3 or 'GT3' - greater than 3 |
# |Pstatus| 부모님과 동거 |   'T' - living together or 'A' - apart |
# |Medu| 어머니 교육수준 | 0 - none, 1 - primary education, 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education |
# |Fedu| 아버지 교육수준 | 0 - none, 1 - primary education, 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education |
# |Mjob| 어머니 직업 | 'teacher', 'health' care related, civil 'services' |
# |Fjob| 아버지 직업 | 'teacher', 'health' care related, civil 'services' |
# |reason| 학교선택 이유 | close to 'home', school 'reputation', 'course' preference or 'other' |
# |guardian| 학생의 보호자 | 'mother', 'father' or 'other' |
# |traveltime| 이동시간 | 1 - < 15 min, 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour |
# |studytime| 학습시간 | 1 - < 2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours |
# |failures| 유급 | n if 1<=n<3, else 4 |
# |schoolsup| 방과 후 교육 | yes or no |
# |famsup| 가족 교육| yes or no |
# |paid| 지출금액 | yes or no |
# |activities|교외 활동|yes or no|
# |nursery| 보육원 참석 |yes or no|
# |higher|고등교육 희망|yes or no|
# |internet|인터넷 가능여부| yes or no |
# |romantic| 이성관계 | yes or no |
# |famrel| 가족관계 | from 1 - very bad to 5 - excellent
# |freetime| 자유시간 |from 1 - very low to 5 - very high |
# |goout| 친구와 외출 |from 1 - very low to 5 - very high|
# |Dalc| 하루 알콜 섭취 |from 1 - very low to 5 - very high|
# |Walc| 주간 알콜 섭취 | from 1 - very low to 5 - very high |
# |health| 건강상태 | from 1 - very bad to 5 - very good |
# |absences| 결석 횟수 |from 0 to 93 |

# %% [markdown]
# ### Library & Data Import

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error

# %%
X_train = pd.read_csv('../Datasets/Student_X_train.csv')
X_test = pd.read_csv('../Datasets/Student_X_test.csv')
y_train = pd.read_csv('../Datasets/Student_y_train.csv')

# %%
X_train
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1714     GP   F   18       U     GT3       T     4     3     other
# 1         1254     GP   F   17       U     GT3       T     4     3    health
# 2         1639     GP   F   16       R     GT3       T     4     4    health
# 3         1118     GP   M   16       U     GT3       T     4     4  services
# 4         1499     GP   M   19       U     GT3       T     3     2  services
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 673       1074     GP   M   15       U     GT3       T     4     4  services
# 674       1044     GP   M   15       R     GT3       T     4     4     other
# 675       1078     GP   M   17       U     LE3       T     4     4     other
# 676       1055     MS   M   17       R     GT3       T     1     1     other
# 677       1394     GP   F   17       U     GT3       T     3     2    health
#
#      ... romantic famrel freetime  goout  Dalc  Walc health absences  G1  G2
# 0    ...       no      4        3      3     1     1      3        0  14  13
# 1    ...      yes      4        4      3     1     3      4        0  13  15
# 2    ...       no      2        4      4     2     3      4        6  10  11
# 3    ...       no      5        3      3     1     3      5        0  15  13
# 4    ...      yes      4        5      4     1     1      4        0   5   0
# ..   ...      ...    ...      ...    ...   ...   ...    ...      ...  ..  ..
# 673  ...       no      5        3      3     1     1      5        4  10  13
# 674  ...      yes      1        3      5     3     5      1        8  12  10
# 675  ...       no      4        1      1     2     2      5        0  12  13
# 676  ...      yes      4        5      5     1     3      2        0  10   9
# 677  ...       no      5        2      2     1     2      5        0  18  18
#
# [678 rows x 33 columns]

# %%
X_test
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1000     GP   F   16       U     GT3       T     4     2  services
# 1         1008     GP   M   19       U     GT3       T     1     2     other
# 2         1013     GP   F   16       U     GT3       T     4     4  services
# 3         1014     GP   F   16       U     GT3       T     3     1  services
# 4         1017     GP   F   15       U     LE3       A     3     4     other
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 361       2032     GP   F   15       R     LE3       T     3     1     other
# 362       2034     GP   M   17       U     GT3       T     3     3  services
# 363       2035     GP   F   16       U     GT3       T     2     3  services
# 364       2036     MS   F   16       U     GT3       T     3     1     other
# 365       2037     MS   M   18       U     GT3       T     4     4   teacher
#
#      ... romantic famrel freetime  goout  Dalc  Walc health absences  G1  G2
# 0    ...       no      4        2      3     1     1      5        2  15  16
# 1    ...       no      4        5      2     2     2      4        3  13  11
# 2    ...       no      3        2      3     1     2      2        6  13  14
# 3    ...       no      4        3      3     1     2      5        4   7   7
# 4    ...      yes      5        3      2     1     1      1        0  10  11
# ..   ...      ...    ...      ...    ...   ...   ...    ...      ...  ..  ..
# 361  ...       no      4        4      2     2     3      3        6  15  15
# 362  ...      yes      4        3      4     2     3      4       12  12  12
# 363  ...       no      2        3      1     1     1      3        2  16  16
# 364  ...       no      3        1      3     1     3      1        0   8   6
# 365  ...       no      3        2      4     1     4      2        4  15  14
#
# [366 rows x 33 columns]

# %%
y_train
# Out:
#      StudentID  G3
# 0         1714  14
# 1         1254  15
# 2         1639  11
# 3         1118  13
# 4         1499   0
# ..         ...  ..
# 673       1074  14
# 674       1044  11
# 675       1078  13
# 676       1055  10
# 677       1394  18
#
# [678 rows x 2 columns]

# %%
X_train.isna().sum()
# Out:
# StudentID     0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# StudentID     0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678 entries, 0 to 677
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   678 non-null    int64
#  1   school      678 non-null    object
#  2   sex         678 non-null    object
#  3   age         678 non-null    int64
#  4   address     678 non-null    object
#  5   famsize     678 non-null    object
#  6   Pstatus     678 non-null    object
#  7   Medu        678 non-null    int64
#  8   Fedu        678 non-null    int64
#  9   Mjob        678 non-null    object
#  10  Fjob        678 non-null    object
#  11  reason      678 non-null    object
#  12  guardian    678 non-null    object
#  13  traveltime  678 non-null    int64
#  14  studytime   678 non-null    int64
#  15  failures    678 non-null    int64
#  16  schoolsup   678 non-null    object
#  17  famsup      678 non-null    object
#  18  paid        678 non-null    object
#  19  activities  678 non-null    object
#  20  nursery     678 non-null    object
#  21  higher      678 non-null    object
#  22  internet    678 non-null    object
#  23  romantic    678 non-null    object
#  24  famrel      678 non-null    int64
#  25  freetime    678 non-null    int64
#  26  goout       678 non-null    int64
#  27  Dalc        678 non-null    int64
#  28  Walc        678 non-null    int64
#  29  health      678 non-null    int64
#  30  absences    678 non-null    int64
#  31  G1          678 non-null    int64
#  32  G2          678 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 174.9+ KB

# %%
StudentID = X_test['StudentID'].copy()

X_train = X_train.drop(columns=['StudentID'])
X_test = X_test.drop(columns=['StudentID'])
y_train = y_train.drop(columns=['StudentID'])

# %%
X_train_cat = X_train.select_dtypes('object').copy()
X_test_cat = X_test.select_dtypes('object').copy()

ohe = OneHotEncoder(sparse=False)
ohe.fit(X_train_cat)

X_train_ohe = ohe.transform(X_train_cat)
X_test_ohe = ohe.transform(X_test_cat)

# %%
X_train_num = X_train.select_dtypes(exclude='object').copy()
X_test_num = X_test.select_dtypes(exclude='object').copy()

scaler = MinMaxScaler()
scaler.fit(X_train_num)

X_train_sca = scaler.transform(X_train_num)
X_test_sca = scaler.transform(X_test_num)

# %%
X_TRAIN = np.concatenate([X_train_ohe, X_train_sca], axis=1)
X_TEST = np.concatenate([X_test_ohe, X_test_sca], axis=1)

y_TRAIN = y_train['G3']

print(X_train.shape, X_test.shape, y_TRAIN.shape)
# Out:
# (678, 32) (366, 32) (678,)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_TRAIN, y_TRAIN, test_size = 0.25, random_state=1234)

print(xtrain.shape, xtest.shape, ytrain.shape, ytest.shape)
# Out:
# (508, 58) (170, 58) (508,) (170,)

# %%
def make_models(xtrain, xtest, ytrain, ytest):
    model1 = LinearRegression().fit(xtrain, ytrain)
    print('model1', get_score(model1, xtrain, xtest, ytrain, ytest))
    
    model2 = RandomForestRegressor(random_state=2022).fit(xtrain, ytrain)
    print('model2', get_score(model2, xtrain, xtest, ytrain, ytest))
    
    for d in range(3,8):
        model2 = RandomForestRegressor(500, max_depth=d, random_state=2022).fit(xtrain, ytrain)
        print('model2', d, get_score(model2, xtrain, xtest, ytrain, ytest))

# %%
def get_score(model, xtrain, xtest, ytrain, ytest):
    A = model.score(xtrain, ytrain)
    ypred = model.predict(xtest)
    print(ypred)
    B = mean_squared_error(ytest, ypred)
    
    return f'{A:.4} {B:.4}'

# %%
make_models(xtrain, xtest, ytrain, ytest)
# Out:
# [12.5     9.8125  5.     13.125  13.1875 15.625  10.375  11.125  12.125
#  14.4375 14.25    9.5     7.875   9.375  12.8125  8.75   18.6875 10.375
#   4.8125  6.     14.5    16.375  13.1875 11.0625  9.6875  4.9375 13.25
#  10.28657682 15.63096143 10.81272803 11.07193799  0.232      12.16211849
#  10.71492527 15.17010332 15.34571034 16.09650808  9.27241797  5.8037746
#  11.09758236 10.55478206  8.06299921  7.80762701 11.07120529 10.47042679
#  10.32107248  7.46514884 15.40408643  9.81929933  4.54561406  8.27206377
#  15.45451957 10.36845644 10.88719744 15.37522107 14.34771409 13.22011158
#  10.53298136 10.80529179 13.28724905 10.77960535 11.01506501 12.16593001
#  13.31674873 10.53309001 14.29941781 10.67714977 12.51848997 12.68496907
#   9.57483835 15.53840884 18.3409175  10.23133345  7.93919697 14.1384085
#   7.84212101 11.12583451 12.7575651  17.34789204 10.71444839 10.94116981
#  10.87292521 15.21564866 10.55780971 12.6687036  14.72505624 12.40676203
#  15.22408029  7.61115235 15.62879788 10.96701795  7.74934299 11.12903135
#  12.01759159 11.35736384 12.62693084 10.82557524 11.04698405  9.51465059
#  12.96735299 10.22837523  9.68876686  7.75241729 15.67295503 12.47939896
#  17.16247302 12.45119315 10.69818143  8.05498915 11.00528478 12.88951226
#  14.68823592 12.48807576 10.36755255  7.23685777  7.47801224 10.38525092
#  10.69789859 10.38122058 10.3084363   0.216       7.75749356  8.04278563
#  12.9753919   6.23766031]
# model2 7 0.9724 3.07

# %%
final_model = LinearRegression().fit(xtrain, ytrain)
print('final_model', get_score(final_model, xtrain, xtest, ytrain, ytest))
# Out:
# [12.5     9.8125  5.     13.125  13.1875 15.625  10.375  11.125  12.125
#  14.4375 14.25    9.5     7.875   9.375  12.8125  8.75   18.6875 10.375
#   4.8125  6.     14.5    16.375  13.1875 11.0625  9.6875  4.9375 13.25
#  12.875  12.5625 19.0625 14.625  10.625  11.0625 13.     13.625   4.5625
#  11.     13.3125 16.375  12.25   10.     12.875  12.0625 11.      9.125
#  16.      8.0625  4.125   9.625   6.6875 11.4375  8.3125 12.     13.
#  14.0625 10.375  13.6875  8.75    7.1875  8.375  13.75    9.     15.1875
#   8.25   12.75    8.6875 12.1875  9.0625 16.6875  8.625   8.1875 10.875
#  10.125  14.8125 10.8125 11.5     1.     12.5625 12.125  15.125  13.875
#  16.75    9.625   5.375  11.4375 10.25    8.0625  9.625  11.375   9.625
#   9.5     7.375  14.125   9.9375  6.1875  7.875  15.5    10.25   11.5
#  15.     14.75   13.125  10.125  11.125  13.     11.0625 11.5    13.25
#  13.5     9.5    14.1875 11.375  12.     12.25    9.625  15.75   19.3125
#   9.875   7.375  13.9375  6.6875 11.3125 12.125  18.5625 10.8125 11.625
#  11.625  13.875   9.5625 13.25   14.0625 12.25   14.375   6.875  15.5
#  10.75    7.8125 12.5    12.4375 11.375  12.9375 11.9375 11.9375  9.0625
#  13.6875  9.375   9.5     7.875  15.     12.0625 16.875  12.1875 11.125
#   8.4375 11.75   13.25   14.375  12.625   9.8125  6.875   5.     10.4375
#   9.8125 10.125   9.1875 -0.6875  8.5     6.8125 13.3125  7.    ]
# final_model 0.8788 3.656

# %%
y_pred = final_model.predict(X_TEST)

obj = {'StudentID' : StudentID,
        'G3' : y_pred
}
result = pd.DataFrame(obj)
result.to_csv('./result.csv', index=False)
